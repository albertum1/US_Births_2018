# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

df = pd.read_csv('abalone.csv')

# %%
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
df.corr()
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
#
#                 Viscera weight  Shell weight     Rings
# Length                0.903018      0.897706  0.556720
# Diameter              0.899724      0.905330  0.574660
# Height                0.798319      0.817338  0.557467
# Whole weight          0.966375      0.955355  0.540390
# ...

# %%
sns.pairplot(df, hue='Sex',diag_kind='hist', plot_kws={'alpha': 0.3})

# %%
sns.scatterplot(x='Rings', y='Shucked weight', data= df)

# %%
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
df['waste'] = df['Whole weight'] - df['Shucked weight'] - df['Viscera weight'] - df['Shell weight']

# %%
df['waste'] = df['waste']/df['Whole weight']

# %%
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings     waste
# 0             0.1010        0.1500     15  0.074903
# 1             0.0485        0.0700      7  0.033259
# ...

# %%
sns.distplot(df['waste'])

# %%
df['waste'].describe()
# Out:
# count    4177.000000
# mean        0.053444
# std         0.114132
# min        -4.170616
# 25%         0.037693
# 50%         0.052117
# 75%         0.073643
# max         0.335907
# Name: waste, dtype: float64

# %%
sns.scatterplot(x='Rings', y='Whole weight', data= df)

# %%
df['rings_log'] = np.log(df['Rings'])

# %%
sns.scatterplot(x='rings_log', y='Whole weight', data= df)

# %%
df['whole_weight_log'] = np.log(df['Whole weight'])

# %%
sns.scatterplot(x='rings_log', y='whole_weight_log', data= df)

# %%
sns.scatterplot(x='Rings', y='whole_weight_log', data= df)

# %%
df['sqrt_weight'] = np.sqrt(df['Whole weight'])

# %%
sns.scatterplot(x='Rings', y='sqrt_weight', data= df)

# %%
df['sqrt_rings'] = np.sqrt(df['Rings'])

# %%
sns.scatterplot(x='sqrt_rings', y='Whole weight', data= df)

# %%
from sklearn.datasets import load_iris

# %%
_iris = load_iris(return_X_y = True)

# %%
_iris_df = pd.DataFrame(_iris[0])

# %%
_iris_df.corr()
# Out:
#           0         1         2         3
# 0  1.000000 -0.117570  0.871754  0.817941
# 1 -0.117570  1.000000 -0.428440 -0.366126
# 2  0.871754 -0.428440  1.000000  0.962865
# 3  0.817941 -0.366126  0.962865  1.000000

# %%
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings     waste  rings_log  \
# 0             0.1010        0.1500     15  0.074903   0.066667
# ...
